# %% [markdown]
# # Vehicle Cut-In Detection
#
# This notebook is made by Ved Verma.
#
# In this notebook I shall explain the code and how to use the code for your own purposes

# %% [markdown]
# ## Approach
#
# Essentially what we do is initialize a window between two lines. The distance between the two lines will be known (In our case it is fixed to 10m).
#
# What we do is check if any vehicle is whithin this window. If yes, then we use the speed using the data provided from the OBD (On-Board Diagnostic) to calculate a TTC (Time To Collision).
#
# If the TTC falls under 0.7s, we initiate a warning.

# %% [markdown]
# ## Importing Necessary Packages
#
# This code section imports all the required packages for this project.
# Make sure you have installed all the packages.

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from ultralytics.solutions import speed_estimation
from tracker import Tracker

# %% [markdown]
# Chooses the YOLO model and uses the pre-trained weights.

# %%
model = YOLO('yolov8s.pt')

# %% [markdown]
# This function tracks the mouse movement and prints the (x, y) coordinates when the mouse cursor is moved within the OpenCV window.

# %%
def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

# %%
cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

# %% [markdown]
# This code segment initializes a video capture object using OpenCV which allows us to read frames from the video file.

# %%
cap = cv2.VideoCapture('0000000_1.mp4')  #Change to the path of the input video file

# %% [markdown]
# This code opens the `classes.txt` which contains all the classes of objects that can be detected using the YOLOv8 model.

# %%
my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

# %% [markdown]
# This segment initializes all the constants.

# %%
fps = cap.get(cv2.CAP_PROP_FPS) #Gets the FrameRate of the video
count = 0 
tracker = Tracker() # Gets the tracker function to allow us to track the vehicles
cy1 = 354 # Defines the y-coordinates of the line where we detect a cut in and collision
cy2 = 412
offset = 6

# %% [markdown]
# This segment initializes an video file `output.mp4` which is the output of the project.

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, fps, (1020, 500))

# %% [markdown]
# This function calculates the time to collision over the 10m window defined by the lines. If the time to collision is less than 0.7s we trigger a warning.

# %%
def check_warning(frame, cx, cy, vehicle_id, x, y):
    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
    distance = 10  # Pre-determined distance in the window
    speed = 15  # Replace with speed data gotten from the OBD
    if (distance / speed) < 0.7:
        cv2.putText(frame, f'WARNING: COLLISION DETECTED', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

# %% [markdown]
# This code processes video frames, detects vehicles, tracks them, and displays warnings based on their position.

# %%
while True:
    # Read the next frame
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if no more frames

    # Process every third frame
    if count % 3 != 0:
        continue

    # Resize frame to 1020x500
    frame = cv2.resize(frame, (1020, 500))

    # Perform object detection (results from model)
    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")

    # Extract bounding boxes for vehicles
    vehicle_list = []
    for index, row in px.iterrows():
        x1, y1, x2, y2, _, d = map(int, row)
        c = class_list[d]
        if c in ['car', 'truck', 'bus', 'motorcycle']:
            vehicle_list.append([x1, y1, x2, y2])

    # Update tracker with bounding box list
    bbox_id = tracker.update(vehicle_list)

    # Draw lines for regions of interest
    cv2.line(frame, (274, cy1), (814, cy1), (255, 255, 255), 1)
    cv2.line(frame, (177, cy2), (927, cy2), (255, 255, 255), 1)

    # Process each tracked vehicle
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = (x3 + x4) // 2
        cy = (y3 + y4) // 2

        # Draw rectangle around vehicle
        cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 1)

        # Display "Vehicle Detected" label
        cv2.putText(frame, f'Vehicle Detected', (x4, y4),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0, 255, 255), 2)

        # Check if vehicle is within vertical range
        if cy2 < (cy + offset) and cy2 > (cy - offset):
            check_warning(frame, cx, cy, id, x4, y4)

    # Write processed frame to output video
    out.write(frame)

    # Display frame
    cv2.imshow("RGB", frame)

    # Exit loop if 'Esc' key is pressed
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Cleanup: Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 1 truck, 1 bench, 450.8ms
# Speed: 9.0ms preprocess, 450.8ms inference, 29.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 motorcycles, 1 truck, 267.3ms
# Speed: 3.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 2 cars, 3 motorcycles, 1 truck, 274.3ms
# Speed: 2.0ms preprocess, 274.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 1 truck, 257.3ms
# Speed: 1.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 252.3ms
# Speed: 2.0ms preprocess, 252.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 4 motorcycles, 2 trucks, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 2 cars, 3 motorcycles, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 5 motorcycles, 2 trucks, 278.8ms
# Speed: 2.0ms preprocess, 278.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 256.0ms
# Speed: 1.0ms preprocess, 256.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 2 cars, 2 motorcycles, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 2 motorcycles, 1 truck, 255.6ms
# Speed: 2.0ms preprocess, 255.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 3 motorcycles, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 1 truck, 266.3ms
# Speed: 1.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 3 motorcycles, 1 truck, 253.8ms
# Speed: 2.0ms preprocess, 253.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 2 cars, 2 motorcycles, 1 truck, 273.6ms
# Speed: 2.0ms preprocess, 273.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 3 motorcycles, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 car, 2 motorcycles, 1 truck, 273.3ms
# Speed: 1.0ms preprocess, 273.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 motorcycle, 1 truck, 259.8ms
# Speed: 3.0ms preprocess, 259.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 motorcycle, 1 truck, 288.2ms
# Speed: 3.0ms preprocess, 288.2ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 2 motorcycles, 287.0ms
# Speed: 2.0ms preprocess, 287.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 car, 3 motorcycles, 1 bench, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 302.2ms
# Speed: 2.0ms preprocess, 302.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 290.7ms
# Speed: 2.0ms preprocess, 290.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 287.8ms
# Speed: 2.0ms preprocess, 287.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 282.7ms
# Speed: 2.0ms preprocess, 282.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 1 motorcycle, 1 truck, 295.7ms
# Speed: 2.0ms preprocess, 295.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 288.7ms
# Speed: 2.0ms preprocess, 288.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 2 trucks, 291.2ms
# Speed: 2.0ms preprocess, 291.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 2 trucks, 274.3ms
# Speed: 2.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 motorcycles, 1 truck, 289.2ms
# Speed: 2.0ms preprocess, 289.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 motorcycles, 1 truck, 287.7ms
# Speed: 3.0ms preprocess, 287.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 2 motorcycles, 300.2ms
# Speed: 2.0ms preprocess, 300.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 3 motorcycles, 1 truck, 295.2ms
# Speed: 2.0ms preprocess, 295.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 2 motorcycles, 280.8ms
# Speed: 2.0ms preprocess, 280.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 3 motorcycles, 258.3ms
# Speed: 3.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 motorcycles, 270.2ms
# Speed: 3.0ms preprocess, 270.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 3 motorcycles, 255.3ms
# Speed: 3.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 motorcycles, 2 trucks, 298.2ms
# Speed: 2.0ms preprocess, 298.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 3 motorcycles, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 2 trucks, 276.3ms
# Speed: 2.0ms preprocess, 276.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 10 cars, 2 motorcycles, 2 trucks, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 282.2ms
# Speed: 2.0ms preprocess, 282.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 motorcycles, 1 truck, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 270.8ms
# Speed: 2.0ms preprocess, 270.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 motorcycles, 1 truck, 265.8ms
# Speed: 2.0ms preprocess, 265.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 motorcycles, 1 truck, 296.9ms
# Speed: 3.0ms preprocess, 296.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 motorcycles, 259.6ms
# Speed: 2.0ms preprocess, 259.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 263.8ms
# Speed: 2.0ms preprocess, 263.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 1 truck, 252.3ms
# Speed: 2.0ms preprocess, 252.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 1 truck, 279.3ms
# Speed: 2.0ms preprocess, 279.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 1 truck, 273.4ms
# Speed: 1.0ms preprocess, 273.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 motorcycle, 1 truck, 274.7ms
# Speed: 2.0ms preprocess, 274.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 motorcycles, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 268.8ms
# Speed: 2.0ms preprocess, 268.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 261.1ms
# Speed: 2.0ms preprocess, 261.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 motorcycles, 1 truck, 282.3ms
# Speed: 2.0ms preprocess, 282.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 2 motorcycles, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 1 truck, 287.2ms
# Speed: 1.0ms preprocess, 287.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 298.6ms
# Speed: 2.0ms preprocess, 298.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 motorcycles, 1 truck, 280.6ms
# Speed: 2.0ms preprocess, 280.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 1 truck, 281.2ms
# Speed: 2.0ms preprocess, 281.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 1 truck, 274.3ms
# Speed: 1.0ms preprocess, 274.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 motorcycle, 1 truck, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 truck, 275.3ms
# Speed: 1.0ms preprocess, 275.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 motorcycle, 1 truck, 271.3ms
# Speed: 1.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 motorcycle, 1 truck, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 275.3ms
# Speed: 1.0ms preprocess, 275.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 260.3ms
# Speed: 3.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 bus, 1 truck, 263.3ms
# Speed: 1.0ms preprocess, 263.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 bus, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 bus, 1 truck, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 1 bus, 1 truck, 269.3ms
# Speed: 3.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 252.3ms
# Speed: 1.0ms preprocess, 252.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 bus, 1 truck, 260.3ms
# Speed: 1.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 bus, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 bus, 1 truck, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 bus, 2 trucks, 252.3ms
# Speed: 1.0ms preprocess, 252.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 bus, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 275.3ms
# Speed: 2.0ms preprocess, 275.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 trucks, 272.3ms
# Speed: 1.0ms preprocess, 272.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 truck, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 278.3ms
# Speed: 2.0ms preprocess, 278.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 288.2ms
# Speed: 1.0ms preprocess, 288.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 287.2ms
# Speed: 2.0ms preprocess, 287.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 287.2ms
# Speed: 3.0ms preprocess, 287.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 trucks, 281.2ms
# Speed: 2.0ms preprocess, 281.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 268.3ms
# Speed: 1.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 253.3ms
# Speed: 1.0ms preprocess, 253.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 262.3ms
# Speed: 1.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 287.2ms
# Speed: 1.0ms preprocess, 287.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 1 traffic light, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 269.3ms
# Speed: 3.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 1 traffic light, 276.3ms
# Speed: 2.0ms preprocess, 276.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 1 traffic light, 274.3ms
# Speed: 2.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 262.3ms
# Speed: 1.0ms preprocess, 262.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 258.3ms
# Speed: 1.0ms preprocess, 258.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 1 traffic light, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 1 truck, 284.3ms
# Speed: 2.0ms preprocess, 284.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 1 truck, 248.3ms
# Speed: 2.0ms preprocess, 248.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 motorcycles, 1 truck, 275.3ms
# Speed: 2.0ms preprocess, 275.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 2 motorcycles, 1 truck, 282.2ms
# Speed: 1.0ms preprocess, 282.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 8 cars, 3 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 3 motorcycles, 1 truck, 246.3ms
# Speed: 2.0ms preprocess, 246.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 3 motorcycles, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 3 motorcycles, 1 truck, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 2 motorcycles, 1 truck, 262.3ms
# Speed: 1.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 7 cars, 3 motorcycles, 1 truck, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 2 motorcycles, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 2 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 1 dog, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 1 bird, 268.3ms
# Speed: 3.0ms preprocess, 268.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 2 trucks, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 1 bird, 247.3ms
# Speed: 1.0ms preprocess, 247.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 1 bird, 252.3ms
# Speed: 2.0ms preprocess, 252.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 3 cars, 2 motorcycles, 1 truck, 1 bird, 287.2ms
# Speed: 3.0ms preprocess, 287.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 1 motorcycle, 1 truck, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 2 motorcycles, 1 truck, 247.3ms
# Speed: 1.0ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 1 truck, 250.3ms
# Speed: 2.0ms preprocess, 250.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 3 motorcycles, 1 truck, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 4 motorcycles, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 5 motorcycles, 1 truck, 248.3ms
# Speed: 1.0ms preprocess, 248.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 4 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 persons, 5 cars, 4 motorcycles, 1 truck, 270.3ms
# Speed: 1.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 persons, 5 cars, 2 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 4 cars, 2 motorcycles, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 5 cars, 1 motorcycle, 1 bus, 1 truck, 1 surfboard, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 4 cars, 2 motorcycles, 1 bus, 1 truck, 279.3ms
# Speed: 2.0ms preprocess, 279.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 3 cars, 2 motorcycles, 1 bus, 1 truck, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 3 cars, 1 motorcycle, 1 truck, 258.3ms
# Speed: 1.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 4 cars, 1 motorcycle, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 4 cars, 2 motorcycles, 1 bus, 1 truck, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 3 cars, 3 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 2 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 4 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 persons, 4 cars, 4 motorcycles, 1 bus, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 4 motorcycles, 1 bus, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 4 cars, 4 motorcycles, 1 bus, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 1 bus, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 4 cars, 4 motorcycles, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 5 motorcycles, 1 truck, 250.3ms
# Speed: 2.0ms preprocess, 250.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 4 motorcycles, 1 truck, 259.3ms
# Speed: 1.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 248.3ms
# Speed: 2.0ms preprocess, 248.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 5 cars, 2 motorcycles, 1 truck, 250.4ms
# Speed: 2.0ms preprocess, 250.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 persons, 7 cars, 2 motorcycles, 1 truck, 252.3ms
# Speed: 2.0ms preprocess, 252.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 5 cars, 2 motorcycles, 1 truck, 279.3ms
# Speed: 2.0ms preprocess, 279.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 1 motorcycle, 1 truck, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 persons, 5 cars, 2 motorcycles, 1 truck, 265.3ms
# Speed: 1.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 2 motorcycles, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 2 motorcycles, 1 truck, 1 toilet, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 4 motorcycles, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 1 truck, 265.3ms
# Speed: 1.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 280.3ms
# Speed: 2.0ms preprocess, 280.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 6 cars, 3 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 2 motorcycles, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 2 motorcycles, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 5 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 1 truck, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 3 motorcycles, 1 truck, 257.3ms
# Speed: 1.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 1 truck, 1 traffic light, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 1 truck, 255.3ms
# Speed: 1.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 1 truck, 271.3ms
# Speed: 3.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 4 motorcycles, 1 truck, 1 traffic light, 249.4ms
# Speed: 2.0ms preprocess, 249.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 1 truck, 1 traffic light, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 4 motorcycles, 1 truck, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 1 truck, 1 traffic light, 253.4ms
# Speed: 2.0ms preprocess, 253.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 5 motorcycles, 2 trucks, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 5 motorcycles, 2 trucks, 249.4ms
# Speed: 1.0ms preprocess, 249.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 5 motorcycles, 1 truck, 1 traffic light, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 1 truck, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 1 truck, 259.3ms
# Speed: 1.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 2 trucks, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 4 motorcycles, 3 trucks, 255.3ms
# Speed: 1.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 1 truck, 263.3ms
# Speed: 3.0ms preprocess, 263.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 2 buss, 2 trucks, 1 traffic light, 253.3ms
# Speed: 3.0ms preprocess, 253.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 4 motorcycles, 3 trucks, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 5 motorcycles, 3 trucks, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 3 trucks, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 3 trucks, 248.3ms
# Speed: 1.0ms preprocess, 248.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 4 motorcycles, 3 trucks, 1 traffic light, 255.3ms
# Speed: 1.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 3 motorcycles, 3 trucks, 1 traffic light, 259.3ms
# Speed: 1.0ms preprocess, 259.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 3 trucks, 1 traffic light, 283.2ms
# Speed: 2.0ms preprocess, 283.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 3 motorcycles, 3 trucks, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 7 cars, 4 motorcycles, 3 trucks, 298.2ms
# Speed: 3.0ms preprocess, 298.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 8 cars, 3 motorcycles, 3 trucks, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 8 cars, 4 motorcycles, 3 trucks, 284.3ms
# Speed: 2.0ms preprocess, 284.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 4 motorcycles, 3 trucks, 269.3ms
# Speed: 1.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 5 motorcycles, 3 trucks, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 3 trucks, 1 traffic light, 274.3ms
# Speed: 2.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 3 motorcycles, 3 trucks, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 3 trucks, 261.4ms
# Speed: 2.0ms preprocess, 261.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 3 motorcycles, 3 trucks, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 7 cars, 2 motorcycles, 3 trucks, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 8 cars, 2 motorcycles, 3 trucks, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 10 cars, 1 motorcycle, 3 trucks, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 3 trucks, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 3 trucks, 1 traffic light, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 2 motorcycles, 3 trucks, 287.2ms
# Speed: 2.0ms preprocess, 287.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 3 motorcycles, 3 trucks, 2 backpacks, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 3 trucks, 2 backpacks, 250.3ms
# Speed: 1.0ms preprocess, 250.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 3 motorcycles, 3 trucks, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 3 trucks, 1 backpack, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 3 trucks, 248.3ms
# Speed: 2.0ms preprocess, 248.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 3 trucks, 1 traffic light, 1 backpack, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 3 trucks, 1 backpack, 247.3ms
# Speed: 2.0ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 2 motorcycles, 2 trucks, 2 backpacks, 266.3ms
# Speed: 5.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 1 motorcycle, 3 trucks, 1 backpack, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 bicycle, 7 cars, 1 motorcycle, 3 trucks, 1 traffic light, 1 backpack, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 3 trucks, 1 backpack, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 6 cars, 4 motorcycles, 3 trucks, 2 backpacks, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 3 trucks, 1 backpack, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 4 motorcycles, 2 trucks, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 4 motorcycles, 3 trucks, 291.3ms
# Speed: 2.0ms preprocess, 291.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 4 motorcycles, 3 trucks, 251.4ms
# Speed: 2.0ms preprocess, 251.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 3 trucks, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 5 motorcycles, 3 trucks, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 3 trucks, 299.2ms
# Speed: 1.0ms preprocess, 299.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 3 trucks, 283.2ms
# Speed: 2.0ms preprocess, 283.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 3 trucks, 264.3ms
# Speed: 1.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 3 trucks, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 4 motorcycles, 3 trucks, 264.3ms
# Speed: 1.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 3 trucks, 265.3ms
# Speed: 1.0ms preprocess, 265.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 5 motorcycles, 4 trucks, 1 traffic light, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 4 motorcycles, 3 trucks, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 5 cars, 4 motorcycles, 3 trucks, 280.2ms
# Speed: 2.0ms preprocess, 280.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 3 trucks, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 3 trucks, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 3 trucks, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 4 trucks, 254.3ms
# Speed: 3.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 4 motorcycles, 4 trucks, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 3 trucks, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 4 trucks, 258.4ms
# Speed: 2.0ms preprocess, 258.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 5 trucks, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 3 trucks, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 3 motorcycles, 4 trucks, 253.4ms
# Speed: 1.0ms preprocess, 253.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 motorcycles, 5 trucks, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 6 trucks, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 motorcycles, 4 trucks, 279.3ms
# Speed: 3.0ms preprocess, 279.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 2 motorcycles, 4 trucks, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 bus, 3 trucks, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# ...
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 252.3ms
# Speed: 2.0ms preprocess, 252.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 278.3ms
# Speed: 2.0ms preprocess, 278.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 motorcycle, 2 trucks, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 motorcycle, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 motorcycle, 1 truck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 motorcycle, 1 truck, 273.3ms
# Speed: 1.0ms preprocess, 273.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 motorcycle, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 motorcycle, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 1 motorcycle, 1 truck, 283.2ms
# Speed: 2.0ms preprocess, 283.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 2 motorcycles, 1 truck, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 motorcycles, 1 truck, 282.2ms
# Speed: 2.0ms preprocess, 282.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 269.3ms
# Speed: 2.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 267.3ms
# Speed: 1.0ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 3 motorcycles, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 261.3ms
# Speed: 1.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 motorcycles, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 2 motorcycles, 1 truck, 275.3ms
# Speed: 2.0ms preprocess, 275.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 2 motorcycles, 1 truck, 279.3ms
# Speed: 2.0ms preprocess, 279.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 290.3ms
# Speed: 3.0ms preprocess, 290.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 280.3ms
# Speed: 2.0ms preprocess, 280.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 270.2ms
# Speed: 2.0ms preprocess, 270.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 2 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 274.3ms
# Speed: 2.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 1 motorcycle, 1 truck, 277.3ms
# Speed: 2.0ms preprocess, 277.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 1 motorcycle, 1 truck, 1 tv, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 2 cars, 1 motorcycle, 1 truck, 1 tv, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 motorcycle, 1 truck, 258.3ms
# Speed: 2.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 motorcycle, 1 truck, 262.3ms
# Speed: 1.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 truck, 247.3ms
# Speed: 3.0ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 car, 1 motorcycle, 1 truck, 261.3ms
# Speed: 3.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 motorcycles, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 motorcycles, 1 truck, 254.3ms
# Speed: 2.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 3 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 motorcycle, 1 truck, 272.3ms
# Speed: 2.0ms preprocess, 272.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 249.3ms
# Speed: 2.0ms preprocess, 249.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 1 motorcycle, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 2 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 3 motorcycles, 1 truck, 1 traffic light, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cars, 2 motorcycles, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 2 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 1 motorcycle, 2 trucks, 263.3ms
# Speed: 1.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 motorcycles, 1 truck, 271.3ms
# Speed: 1.0ms preprocess, 271.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 3 motorcycles, 1 truck, 273.3ms
# Speed: 2.0ms preprocess, 273.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 4 motorcycles, 1 truck, 276.3ms
# Speed: 2.0ms preprocess, 276.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 4 cars, 3 motorcycles, 1 truck, 270.3ms
# Speed: 2.0ms preprocess, 270.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 4 motorcycles, 1 truck, 278.3ms
# Speed: 2.0ms preprocess, 278.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 motorcycles, 1 truck, 262.3ms
# Speed: 2.0ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 motorcycles, 1 truck, 268.3ms
# Speed: 2.0ms preprocess, 268.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 motorcycles, 1 truck, 295.2ms
# Speed: 2.0ms preprocess, 295.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 1 motorcycle, 1 truck, 267.3ms
# Speed: 2.0ms preprocess, 267.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 1 motorcycle, 1 truck, 255.3ms
# Speed: 2.0ms preprocess, 255.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 3 motorcycles, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 1 truck, 264.3ms
# Speed: 2.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 5 motorcycles, 1 truck, 257.3ms
# Speed: 2.0ms preprocess, 257.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 3 motorcycles, 1 truck, 272.3ms
# Speed: 3.0ms preprocess, 272.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 6 cars, 5 motorcycles, 1 truck, 263.3ms
# Speed: 1.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cars, 4 motorcycles, 1 truck, 276.3ms
# Speed: 2.0ms preprocess, 276.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 4 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 3 motorcycles, 1 bus, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 3 motorcycles, 1 bus, 1 truck, 276.3ms
# Speed: 1.0ms preprocess, 276.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 2 motorcycles, 1 bus, 1 truck, 251.3ms
# Speed: 2.0ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 3 motorcycles, 1 truck, 282.2ms
# Speed: 2.0ms preprocess, 282.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 4 cars, 5 motorcycles, 1 truck, 258.3ms
# Speed: 1.0ms preprocess, 258.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 4 cars, 3 motorcycles, 1 truck, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 5 cars, 3 motorcycles, 1 truck, 259.3ms
# Speed: 2.0ms preprocess, 259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 6 cars, 5 motorcycles, 1 truck, 281.2ms
# Speed: 2.0ms preprocess, 281.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 5 cars, 4 motorcycles, 1 truck, 274.3ms
# Speed: 1.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 7 cars, 4 motorcycles, 1 truck, 254.3ms
# Speed: 1.0ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 4 motorcycles, 1 truck, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 5 motorcycles, 1 truck, 266.3ms
# Speed: 1.0ms preprocess, 266.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 persons, 5 cars, 3 motorcycles, 1 truck, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 4 motorcycles, 1 truck, 253.3ms
# Speed: 2.0ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 5 motorcycles, 2 trucks, 266.3ms
# Speed: 2.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 cars, 2 motorcycles, 1 truck, 278.3ms
# Speed: 2.0ms preprocess, 278.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 1 motorcycle, 1 truck, 256.3ms
# Speed: 2.0ms preprocess, 256.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 motorcycle, 2 trucks, 265.3ms
# Speed: 2.0ms preprocess, 265.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 3 cars, 1 motorcycle, 1 truck, 271.3ms
# Speed: 2.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 1 motorcycle, 1 truck, 263.3ms
# Speed: 2.0ms preprocess, 263.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 1 motorcycle, 1 bus, 1 truck, 276.3ms
# Speed: 1.0ms preprocess, 276.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 268.3ms
# Speed: 1.0ms preprocess, 268.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 persons, 3 cars, 1 motorcycle, 2 trucks, 255.3ms
# Speed: 1.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 4 cars, 1 motorcycle, 2 trucks, 261.3ms
# Speed: 2.0ms preprocess, 261.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)

# %% [markdown]
# ## END
